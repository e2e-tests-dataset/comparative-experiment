# %%
import pandas as pd
import numpy as np
import glob

# %%
dfs = []
for path in glob.glob('E2E-DATASET/**/**/results.csv'):
    dfs.append(pd.read_csv(path, index_col=0))
dfs.append(pd.read_csv('DEFECTS4J/LangBase/target/surefire-reports/org.apache.commons.GetMetricsTest-output.txt', index_col=0))
df = pd.concat(dfs)

# %%
df
# Out:
#                                                        name     time  \
# app
# WebApp-3                                 checkShowAdminPage  214.821
# WebApp-3                                 checkShowAdminPage  216.962
# WebApp-3                                 checkShowAdminPage  228.756
# WebApp-3                                 checkShowAdminPage  201.606
# WebApp-3                                 checkShowAdminPage  219.494
# WebApp-3                                 checkShowAdminPage  178.676
# WebApp-3                                 checkShowAdminPage  213.919
# WebApp-3                                 checkShowAdminPage  206.101
# WebApp-3                                 checkShowAdminPage  202.807
# WebApp-3                                 checkShowAdminPage  184.400
# WebApp-1                                    checkCreateList  175.139
# WebApp-1                                    checkCreateList  232.584
# WebApp-1                                    checkCreateList  159.660
# WebApp-1                                    checkCreateList  228.122
# WebApp-1                                    checkCreateList  193.355
# WebApp-1                                    checkCreateList  169.683
# WebApp-1                                    checkCreateList  200.166
# WebApp-1                                    checkCreateList  205.901
# WebApp-1                                    checkCreateList  157.863
# WebApp-1                                    checkCreateList  175.866
# WebApp-2                                  checkCreateCourse  181.352
# WebApp-2                                  checkCreateCourse  171.786
# WebApp-2                                  checkCreateCourse  162.258
# WebApp-2                                  checkCreateCourse  169.726
# WebApp-2                                  checkCreateCourse  179.274
# WebApp-2                                  checkCreateCourse  194.731
# WebApp-2                                  checkCreateCourse  120.625
# WebApp-2                                  checkCreateCourse  164.610
# WebApp-2                                  checkCreateCourse  183.736
# WebApp-2                                  checkCreateCourse  172.686
# ...                                                     ...      ...
# Lang      AnnotationUtilsTest#testIsValidAnnotationMembe...    0.000
# Lang      AnnotationUtilsTest#testIsValidAnnotationMembe...    0.000
# Lang      AnnotationUtilsTest#testIsValidAnnotationMembe...    0.001
# Lang      AnnotationUtilsTest#testIsValidAnnotationMembe...    0.000
# Lang      AnnotationUtilsTest#testIsValidAnnotationMembe...    0.000
# Lang      AnnotationUtilsTest#testIsValidAnnotationMembe...    0.001
# Lang      AnnotationUtilsTest#testIsValidAnnotationMembe...    0.000
# Lang      AnnotationUtilsTest#testIsValidAnnotationMembe...    0.001
# Lang      AnnotationUtilsTest#testIsValidAnnotationMembe...    0.000
# Lang      AnnotationUtilsTest#testIsValidAnnotationMembe...    0.001
# Lang      AnnotationUtilsTest#testIsValidAnnotationMembe...    0.000
# Lang      AnnotationUtilsTest#testIsValidAnnotationMembe...    0.000
# Lang      AnnotationUtilsTest#testIsValidAnnotationMembe...    0.000
# Lang      AnnotationUtilsTest#testIsValidAnnotationMembe...    0.000
# Lang      AnnotationUtilsTest#testIsValidAnnotationMembe...    0.000
# Lang      AnnotationUtilsTest#testIsValidAnnotationMembe...    0.000
# Lang      AnnotationUtilsTest#testIsValidAnnotationMembe...    0.000
# Lang      AnnotationUtilsTest#testIsValidAnnotationMembe...    0.000
# Lang      AnnotationUtilsTest#testIsValidAnnotationMembe...    0.001
# Lang      AnnotationUtilsTest#testIsValidAnnotationMembe...    0.000
# Lang      AnnotationUtilsTest#testIsValidAnnotationMembe...    0.000
# Lang      AnnotationUtilsTest#testIsValidAnnotationMembe...    0.000
# Lang      AnnotationUtilsTest#testIsValidAnnotationMembe...    0.000
# Lang      AnnotationUtilsTest#testIsValidAnnotationMembe...    0.001
# Lang      AnnotationUtilsTest#testIsValidAnnotationMembe...    0.000
# Lang      AnnotationUtilsTest#testIsValidAnnotationMembe...    0.001
# Lang      AnnotationUtilsTest#testIsValidAnnotationMembe...    0.000
# Lang      AnnotationUtilsTest#testIsValidAnnotationMembe...    0.000
# Lang      AnnotationUtilsTest#testIsValidAnnotationMembe...    0.000
# Lang      AnnotationUtilsTest#testIsValidAnnotationMembe...    0.000
#
#                maxMem      maxCpu
# app
# WebApp-3   815.664062  307.290751
# WebApp-3   775.894531  321.570201
# WebApp-3   778.406250  311.267880
# WebApp-3   792.773438  326.338440
# WebApp-3   780.578125  308.657614
# WebApp-3   766.972656  281.869815
# WebApp-3   782.078125  326.102843
# WebApp-3   816.882812  279.805646
# WebApp-3   817.027344  308.681061
# WebApp-3   789.433594  297.482921
# WebApp-1   831.937500  358.405788
# WebApp-1   837.324219  618.656756
# WebApp-1   854.675781  317.667504
# WebApp-1   770.402344  327.194014
# WebApp-1   775.835938  325.980499
# WebApp-1   767.835938  315.583789
# WebApp-1   850.398438  378.709538
# WebApp-1   852.050781  351.814881
# WebApp-1   834.152344  324.899161
# WebApp-1   824.812500  331.034602
# WebApp-2  1026.046875  403.493088
# WebApp-2  1063.898438  335.769665
# WebApp-2  1033.578125  392.466741
# WebApp-2  1041.855469  337.286567
# WebApp-2  1037.453125  314.260298
# WebApp-2  1046.511719  319.281256
# WebApp-2  1078.046875  340.679391
# WebApp-2  1086.042969  359.800692
# WebApp-2  1012.863281  385.709272
# WebApp-2  1032.906250  365.206416
# ...               ...         ...
# Lang        21.000000    0.000000
# Lang        22.000000    0.000000
# Lang        23.000000    0.000000
# Lang        24.000000    0.000000
# Lang        24.000000    0.000000
# Lang        25.000000    0.000000
# Lang        25.000000    0.000000
# Lang        26.000000    0.500000
# Lang        27.000000    0.000000
# Lang        27.000000    0.000000
# Lang        28.000000    0.000000
# Lang        29.000000    0.000000
# Lang        29.000000    1.000000
# Lang        30.000000    0.000000
# Lang        31.000000    0.000000
# Lang        32.000000    0.000000
# Lang        32.000000    0.000000
# Lang        33.000000    0.000000
# Lang        34.000000    0.000000
# Lang        34.000000    0.000000
# Lang        35.000000    0.000000
# Lang        36.000000    0.000000
# Lang        36.000000    0.000000
# Lang        37.000000    0.000000
# Lang        37.000000    0.000000
# Lang        38.000000    0.000000
# Lang        39.000000    0.000000
# Lang        39.000000    0.000000
# Lang        40.000000    0.000000
# Lang        41.000000    0.000000
#
# [150 rows x 4 columns]

# %%
boxplot = df.boxplot(column=['time'], by='name', figsize=(12,4))
boxplot
boxplot2 = df.boxplot(column=['maxMem'], by='name', figsize=(12,4))
boxplot2
boxplot3 = df.boxplot(column=['maxCpu'], by='name', figsize=(12,4))
boxplot3

# %%
import matplotlib.pyplot as plt
import numpy as np

data_a = [[1,2,5], [5,7,2,2,5], [7,2,5]]
data_b = [[6,4,2], [1,2,5,3,2], [2,3,5,1]]

ticks = ['A', 'B', 'C']

def set_box_color(bp, color):
    plt.setp(bp['boxes'], color=color)
    plt.setp(bp['whiskers'], color=color)
    plt.setp(bp['caps'], color=color)
    plt.setp(bp['medians'], color=color)

plt.figure()

bpl = plt.boxplot(data_a, positions=np.array(range(len(data_a)))*2.0-0.4, sym='', widths=0.6)
bpr = plt.boxplot(data_b, positions=np.array(range(len(data_b)))*2.0+0.4, sym='', widths=0.6)
set_box_color(bpl, '#D7191C') # colors are from http://colorbrewer2.org/
set_box_color(bpr, '#2C7BB6')

# draw temporary red and blue lines and use them to create a legend
plt.plot([], c='#D7191C', label='Apples')
plt.plot([], c='#2C7BB6', label='Oranges')
plt.legend()

plt.xticks(range(0, len(ticks) * 2, 2), ticks)
plt.xlim(-2, len(ticks)*2)
plt.ylim(0, 8)
plt.tight_layout()
plt.savefig('boxcompare.png')
