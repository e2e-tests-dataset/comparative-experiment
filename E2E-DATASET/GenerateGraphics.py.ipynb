# %%
import pandas as pd
import numpy as np
import glob

# %%
dfs = []
for path in glob.glob('**/**/results.csv'):
    dfs.append(pd.read_csv(path, index_col=0))
df = pd.concat(dfs)

# %%
df
# Out:
#         app                name     time       maxMem      maxCpu
# 0  WebApp-3  checkShowAdminPage  214.821   815.664062  307.290751
# 1  WebApp-3  checkShowAdminPage  216.962   775.894531  321.570201
# 2  WebApp-3  checkShowAdminPage  228.756   778.406250  311.267880
# 3  WebApp-3  checkShowAdminPage  201.606   792.773438  326.338440
# 4  WebApp-3  checkShowAdminPage  219.494   780.578125  308.657614
# 5  WebApp-3  checkShowAdminPage  178.676   766.972656  281.869815
# 6  WebApp-3  checkShowAdminPage  213.919   782.078125  326.102843
# 7  WebApp-3  checkShowAdminPage  206.101   816.882812  279.805646
# 8  WebApp-3  checkShowAdminPage  202.807   817.027344  308.681061
# 9  WebApp-3  checkShowAdminPage  184.400   789.433594  297.482921
# 0  WebApp-1     checkCreateList  175.139   831.937500  358.405788
# 1  WebApp-1     checkCreateList  232.584   837.324219  618.656756
# 2  WebApp-1     checkCreateList  159.660   854.675781  317.667504
# 3  WebApp-1     checkCreateList  228.122   770.402344  327.194014
# 4  WebApp-1     checkCreateList  193.355   775.835938  325.980499
# 5  WebApp-1     checkCreateList  169.683   767.835938  315.583789
# 6  WebApp-1     checkCreateList  200.166   850.398438  378.709538
# 7  WebApp-1     checkCreateList  205.901   852.050781  351.814881
# 8  WebApp-1     checkCreateList  157.863   834.152344  324.899161
# 9  WebApp-1     checkCreateList  175.866   824.812500  331.034602
# 0  WebApp-2   checkCreateCourse  181.352  1026.046875  403.493088
# 1  WebApp-2   checkCreateCourse  171.786  1063.898438  335.769665
# 2  WebApp-2   checkCreateCourse  162.258  1033.578125  392.466741
# 3  WebApp-2   checkCreateCourse  169.726  1041.855469  337.286567
# 4  WebApp-2   checkCreateCourse  179.274  1037.453125  314.260298
# 5  WebApp-2   checkCreateCourse  194.731  1046.511719  319.281256
# 6  WebApp-2   checkCreateCourse  120.625  1078.046875  340.679391
# 7  WebApp-2   checkCreateCourse  164.610  1086.042969  359.800692
# 8  WebApp-2   checkCreateCourse  183.736  1012.863281  385.709272
# 9  WebApp-2   checkCreateCourse  172.686  1032.906250  365.206416
# 0  WebApp-2       checkDownload  159.408  1048.609375  332.206725
# 1  WebApp-2       checkDownload  167.630  1049.339844  302.346344
# 2  WebApp-2       checkDownload  175.295  1027.968750  322.412540
# 3  WebApp-2       checkDownload  172.486  1032.019531  341.016136
# 4  WebApp-2       checkDownload  168.486  1032.503906  278.099263
# 5  WebApp-2       checkDownload  196.861  1053.921875  310.849397
# 6  WebApp-2       checkDownload  186.515  1069.292969  307.645461
# 7  WebApp-2       checkDownload  174.427   995.304688  295.667311
# 8  WebApp-2       checkDownload  143.652  1105.953125  337.692270
# 9  WebApp-2       checkDownload  164.073  1034.246094  245.412806
# 0  WebApp-2    checkShowProfile  148.382  1064.207031  353.703747
# 1  WebApp-2    checkShowProfile  153.076  1049.820312  412.571140
# 2  WebApp-2    checkShowProfile  162.217  1091.601562  283.166203
# 3  WebApp-2    checkShowProfile  152.660  1050.179688  357.700362
# 4  WebApp-2    checkShowProfile  171.293  1059.867188  285.834169
# 5  WebApp-2    checkShowProfile  145.436  1035.156250  405.608188
# 6  WebApp-2    checkShowProfile  148.756  1045.156250  304.741231
# 7  WebApp-2    checkShowProfile  152.791  1081.519531  379.453483
# 8  WebApp-2    checkShowProfile  186.751  1038.660156  307.659726
# 9  WebApp-2    checkShowProfile  154.880  1118.597656  351.713094

# %%
boxplot = df.boxplot(column=['time'], by='name', figsize=(12,4))
boxplot
boxplot2 = df.boxplot(column=['maxMem'], by='name', figsize=(12,4))
boxplot2
boxplot3 = df.boxplot(column=['maxCpu'], by='name', figsize=(12,4))
boxplot3

# %%
import matplotlib.pyplot as plt
import numpy as np

data_a = [[1,2,5], [5,7,2,2,5], [7,2,5]]
data_b = [[6,4,2], [1,2,5,3,2], [2,3,5,1]]

ticks = ['A', 'B', 'C']

def set_box_color(bp, color):
    plt.setp(bp['boxes'], color=color)
    plt.setp(bp['whiskers'], color=color)
    plt.setp(bp['caps'], color=color)
    plt.setp(bp['medians'], color=color)

plt.figure()

bpl = plt.boxplot(data_a, positions=np.array(range(len(data_a)))*2.0-0.4, sym='', widths=0.6)
bpr = plt.boxplot(data_b, positions=np.array(range(len(data_b)))*2.0+0.4, sym='', widths=0.6)
set_box_color(bpl, '#D7191C') # colors are from http://colorbrewer2.org/
set_box_color(bpr, '#2C7BB6')

# draw temporary red and blue lines and use them to create a legend
plt.plot([], c='#D7191C', label='Apples')
plt.plot([], c='#2C7BB6', label='Oranges')
plt.legend()

plt.xticks(range(0, len(ticks) * 2, 2), ticks)
plt.xlim(-2, len(ticks)*2)
plt.ylim(0, 8)
plt.tight_layout()
plt.savefig('boxcompare.png')
